# %% [markdown]
# # Lab Inferential Statistics

# %%
import pandas as pd
import numpy as np
import scipy.stats as st
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import ttest_1samp
from scipy.stats import t

# %% [markdown]
# ## One tailed T-test

# %% [markdown]
# In a packing plant, a machine packs cartons with jars. It is supposed that a new machine will pack faster on the average than the machine currently used. To test that hypothesis, the times it takes each machine to pack ten cartons are recorded. The results, in seconds, are shown in the tables in the file *files_for_lab/machine.txt*. Assume that there is sufficient evidence to conduct the t test, does the data provide sufficient evidence to show if one machine is better than the other?

# %%
machine = pd.read_csv('files_for_lab/machine_new.txt', sep='\t')
machine
# Out:
#    New machine      Old machine
# 0         42.1             42.7
# 1         41.0             43.6
# 2         41.3             43.8
# 3         41.8             43.3
# 4         42.4             42.5
# 5         42.8             43.5
# 6         43.2             43.1
# 7         42.3             41.7
# 8         41.8             44.0
# 9         42.7             44.1

# %%
machine.columns = ['New machine', 'Old machine']

# %% [markdown]
# * H0: mean time of new machine <= mean time of old machine -> mu(43.230000000000004) >= x(42.14)
# * H1: mean time of new machine > mean time of old machine -> mu(43.230000000000004) < x(42.14)
# * Sample = 10
# * One sided (rejection area on the right side)
# * Confidence interval = 0.95

# %%
print(machine['Old machine'].mean())
print(machine['New machine'].mean())
# Out:
# 43.230000000000004
# 42.14

# %%
stat, pval = ttest_1samp(machine['New machine'], popmean=43.230000000000004, alternative='greater') #lower??

# %%
print(pval)
print(stat)
# Out:
# 0.999651681196162
# -5.04331853503833

# %%
#ppf = critical value vs stat-> If 
t.ppf(0.95, df=9)
# Out:
# 1.8331129326536333

# %%
#cdf=p_value vs alpha
st.t.cdf(stat, df=9)
# Out:
# 0.00034831880383795163

# %%
ttest_1samp(machine['New machine'], 43.230000000000004,  alternative='greater') #why a I getting different results?
# Out:
# TtestResult(statistic=-5.04331853503833, pvalue=0.999651681196162, df=9)

# %% [markdown]
# We have to accept H0 because p-value=0.999651681196162 is > alpha = 0.05 and stat = -5.043 < critical value = 1.83

# %% [markdown]
# ## Matched Pairs Test

# %% [markdown]
# In this challenge we will compare dependent samples of data describing our Pokemon (file files_for_lab/pokemon.csv). Our goal is to see whether there is a significant difference between each Pokemon's defense and attack scores. Our hypothesis is that the defense and attack scores are equal. Compare the two columns to see if there is a statistically significant difference between them and comment your result.

# %%
pokemon = pd.read_csv('files_for_lab/pokemon.csv')
pokemon
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %% [markdown]
# * Ho: attack = defense
# * H1: attack != defense
# * Sample = 30
# * Confidence interval = 0.95
# * Two sided

# %%
sample = pokemon.sample(30, random_state=16)
sample['difference'] = sample['Attack']-sample['Defense']
sample.head(30)
# Out:
#        #                   Name    Type 1    Type 2  Total   HP  Attack  \
# 505  455              Carnivine     Grass       NaN    454   74     100
# 324  300                 Skitty    Normal       NaN    260   50      45
# 510  460              Abomasnow     Grass       Ice    494   90      92
# 598  538                  Throh  Fighting       NaN    465  120     100
# 552  493                 Arceus    Normal       NaN    720  120     120
# 551  492       ShayminSky Forme     Grass    Flying    600  100     103
# 208  193                  Yanma       Bug    Flying    390   65      65
# 574  515                Panpour     Water       NaN    316   50      53
# 528  476              Probopass      Rock     Steel    525   60      55
# 741  673                 Gogoat     Grass       NaN    531  123     100
# 351  321                Wailord     Water       NaN    500  170      90
# 327  302    SableyeMega Sableye      Dark     Ghost    480   50      85
# ...

# %%
sample_diff_mean, sample_diff_std = sample['difference'].mean(), sample['difference'].std(ddof=1)
sample_diff_mean, sample_diff_std
# Out:
# (5.433333333333334, 34.54101343613707)

# %%
t = sample_diff_mean / ( sample_diff_std / np.sqrt(sample.shape[0]) )
print("The mean of our samples differences is: {:.2f}".format(sample_diff_mean))
print("The standard deviation of our samples differences is: {:.2f}".format(sample_diff_std))
print("Our t statistics is: {:.2f}".format(t))
# Out:
# The mean of our samples differences is: 5.43
# The standard deviation of our samples differences is: 34.54
# Our t statistics is: 0.86

# %%
df= sample.shape[0] - 1
df
# Out:
# 29

# %% [markdown]
# We have to use T-test because it's < 30

# %%
tc_upper = st.t.ppf(1-(0.05/2),df= sample.shape[0] - 1)
tc_lower = st.t.ppf(1-(0.95/2),df= sample.shape[0] - 1)
print(tc_upper)
print(tc_lower)
# Out:
# 2.045229642132703
# 0.06325175732602374

# %%
st.t.cdf(t,df = sample.shape[0] - 1)
# Out:
# 0.8020044806100265

# %%
st.ttest_rel(sample['Attack'],sample['Defense'])
# Out:
# TtestResult(statistic=0.8615726445356495, pvalue=0.39599103877994724, df=29)

# %% [markdown]
# **Conclusion:** Our statistic(0.86) is inside the acceptance area [0.063, 2.045] and the p-value(0.40) is bigger than alpha(0.05) therefore we have to **accept the H0**.

# %% [markdown]
# ## ANOVA

# %% [markdown]
# ### Part 1

# %% [markdown]
# In this activity, we will look at another example. Your task is to understand the problem and write down all the steps to set up ANOVA. After the next lesson, we will ask you to solve this problem using Python. Here are the steps that you would need to work on: - Null hypothesis - Alternate hypothesis - Level of significance - Test statistic - P-value - F table

# %% [markdown]
# **Setting ANOVA:**
# * H0: all the group means (the power of each microprocessor) are equal
# * H1: any of the means is not equal
# * Level of significance: 95%
# * Test statistic:
# * P-value
# * F table

# %% [markdown]
# Suppose you are working as an analyst in a microprocessor chip manufacturing plant. You have been given the task of analyzing a plasma etching process with respect to changing Power (in Watts) of the plasma beam. Data was collected and provided to you to conduct statistical analysis and check if changing the power of the plasma beam has any effect on the etching rate by the machine. You will conduct ANOVA and check if there is any difference in the mean etching rate for different levels of power. You can find the data *anova_lab_data.xlsx* file in the files_for_lab folder
#
# * State the null hypothesis
# * State the alternate hypothesis
# * What is the significance level
# * What are the degrees of freedom of model, error terms, and total DoF
# Data was collected randomly and provided to you in the table as shown: link to the image - Data

# %%
data = pd.read_excel('files_for_lab/anova_lab_data.xlsx')
data
# Out:
#    Power   Etching Rate
# 0   160 W          5.43
# 1   180 W          6.24
# 2   200 W          8.79
# 3   160 W          5.71
# 4   180 W          6.71
# 5   200 W          9.20
# 6   160 W          6.22
# 7   180 W          5.98
# 8   200 W          7.90
# 9   160 W          6.01
# 10  180 W          5.66
# 11  200 W          8.15
# 12  160 W          5.59
# 13  180 W          6.60
# 14  200 W          7.55

# %%
data.columns=['Power','Etching Rate']

# %%
data['Power'].value_counts()
# Out:
# 160 W    5
# 180 W    5
# 200 W    5
# Name: Power, dtype: int64

# %%
group_df = data.groupby('Power')['Etching Rate'].agg(power_mean='mean',Samples='size').reset_index()
group_df
# Out:
#    Power  power_mean  Samples
# 0  160 W       5.792        5
# 1  180 W       6.238        5
# 2  200 W       8.318        5

# %%
data['power_count'] = data.groupby('Power').cumcount()
data_pivot = data.pivot(index='power_count', columns = 'Power', values = 'Etching Rate')
data_pivot.columns = ['Power_'+str(x) for x in data_pivot.columns.values]
data_pivot.head()
# Out:
#              Power_160 W  Power_180 W  Power_200 W
# power_count
# 0                   5.43         6.24         8.79
# 1                   5.71         6.71         9.20
# 2                   6.22         5.98         7.90
# 3                   6.01         5.66         8.15
# 4                   5.59         6.60         7.55

# %%
data_pivot.mean()
# Out:
# Power_160 W    5.792
# Power_180 W    6.238
# Power_200 W    8.318
# dtype: float64

# %% [markdown]
# ### Part 2

# %% [markdown]
# * In this section, use the Python to conduct ANOVA.
# * What conclusions can you draw from the experiment and why?

# %%
st.f_oneway(data[data['Power'] == '160 W']['Etching Rate'], data[data['Power'] == '180 W']['Etching Rate'], 
            data[data['Power'] == '200 W']['Etching Rate'])[1]
# Out:
# 7.506584272358903e-06

# %%
st.f_oneway(data_pivot['Power_160 W'], data_pivot['Power_180 W'], data_pivot['Power_200 W'])
# Out:
# F_onewayResult(statistic=36.87895470100505, pvalue=7.506584272358903e-06)

# %% [markdown]
# We have to reject Ho because p-value < alpha.
